# %% [markdown]
# <h1 style="text-align:center;font-size:50px; background-color:pink; color: white"> Vaccines Clean up Process <h1>

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy.sql import text

# %%
csv_path = "./maryland_vaccinations.csv"
df = pd.read_csv(csv_path)

# %%
df
# Out:
#       OBJECTID        VACCINATION_DATE  \
# 0            1  2020/12/23 15:00:00+00
# 1            2  2021/01/04 15:00:00+00
# 2            3  2021/01/08 15:00:00+00
# 3            4  2021/01/10 15:00:00+00
# 4            5  2021/01/11 15:00:00+00
# ...        ...                     ...
# 3930      3931  2021/05/16 15:00:00+00
# 3931      3932  2021/05/17 15:00:00+00
# 3932      3933  2021/05/18 15:00:00+00
# 3933      3934  2021/05/19 15:00:00+00
# 3934      3935  2021/05/20 15:00:00+00
#
#                                                  County  FirstDoseDaily  \
# 0                                                   NaN             1.0
# 1                                                   NaN             1.0
# 2                                                   NaN          8000.0
# 3                                                   NaN             1.0
# 4                                                   NaN             NaN
# ...                                                 ...             ...
# 3930  Worcester                                     ...            29.0
# 3931  Worcester                                     ...           120.0
# 3932  Worcester                                     ...           162.0
# 3933  Worcester                                     ...           115.0
# 3934  Worcester                                     ...            62.0
#
#       FirstDoseCumulative  SecondDoseDaily  SecondDoseCumulative  \
# 0                       1              NaN                     0
# 1                       2              NaN                     0
# 2                    8002              NaN                     0
# 3                    8003              NaN                     0
# 4                    8003              1.0                     1
# ...                   ...              ...                   ...
# 3930                25238             20.0                 21246
# 3931                25358            115.0                 21361
# 3932                25520            124.0                 21485
# 3933                25635             72.0                 21557
# 3934                25697             59.0                 21616
#
#       SingleDoseDaily  SingleDoseCumulative  AtLeastOneDose  FullyVaccinated  \
# 0                 NaN                     0             NaN              NaN
# 1                 NaN                     0             NaN              NaN
# 2                 NaN                     0             NaN              NaN
# 3                 NaN                     0             NaN              NaN
# 4                 NaN                     0             NaN              NaN
# ...               ...                   ...             ...              ...
# 3930              5.0                  1950            34.0             25.0
# 3931             19.0                  1969           139.0            134.0
# 3932             14.0                  1983           176.0            138.0
# 3933              5.0                  1988           120.0             77.0
# 3934             11.0                  1999            73.0             70.0
#
#       FullVaccinatedCumulative  AtLeastOneDoseCumulative
# 0                            0                         1
# 1                            0                         2
# 2                            0                      8002
# 3                            0                      8003
# 4                            1                      8003
# ...                        ...                       ...
# 3930                     23196                     27188
# 3931                     23330                     27327
# 3932                     23468                     27503
# 3933                     23545                     27623
# 3934                     23615                     27696
#
# [3935 rows x 13 columns]
