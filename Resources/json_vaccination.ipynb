# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy.sql import text
from config import password

# %%
connection_string = f"udxenurz:{password}@batyr.db.elephantsql.com/udxenurz"
engine = create_engine(f'postgres://{connection_string}')
print(engine.table_names())
# Out:
# ['cases', 'vaccinations', 'gender']

# %%
df = pd.read_sql_query('select * from vaccinations', con=engine)

# %%
df.head(3)
# Out:
#    ID        DATE     County  FirstDoseDaily  FirstDoseCumulative  \
# 0   1  2020-12-15  Baltimore               1                    1
# 1   2  2020-12-16  Baltimore             122                  123
# 2   3  2020-12-17  Baltimore             189                  312
#
#    SecondDoseDaily  SecondDoseCumulative  SingleDoseDaily  \
# 0                1                     1                0
# 1                0                     1                0
# 2                0                     1                0
#
#    SingleDoseCumulative  AtLeastOneDose  FullyVaccinated  \
# 0                     0               0                0
# 1                     0               0                0
# 2                     0               0                0
#
#    FullVaccinatedCumulative  AtLeastOneDoseCumulative
# 0                         1                         1
# 1                         1                       123
# 2                         1                       312

# %%
dfv = df.drop(columns = ['FirstDoseDaily', 'FirstDoseCumulative', 'SecondDoseDaily', 'SecondDoseCumulative', 'SingleDoseDaily', 'SingleDoseCumulative', 'AtLeastOneDose', 'AtLeastOneDoseCumulative'])
dfv
# Out:
#         ID        DATE           County  FullyVaccinated  \
# 0        1  2020-12-15        Baltimore                0
# 1        2  2020-12-16        Baltimore                0
# 2        3  2020-12-17        Baltimore                0
# 3        4  2020-12-18        Baltimore                0
# 4        5  2020-12-19        Baltimore                0
# ...    ...         ...              ...              ...
# 3984  3985  2021-05-21  Prince George's             3235
# 3985  3986  2021-05-22  Prince George's             2004
# 3986  3987  2021-05-23  Prince George's             1507
# 3987  3988  2021-05-24  Prince George's             2720
# 3988  3989  2021-05-25  Prince George's             1728
#
#       FullVaccinatedCumulative
# 0                            1
# 1                            1
# 2                            1
# 3                            2
# 4                            2
# ...                        ...
# 3984                    322312
# 3985                    324316
# 3986                    325823
# 3987                    328543
# 3988                    330271
#
# [3989 rows x 5 columns]
