# %% [markdown]
# # GENDER CLEAN_UP PROCESS

# %%
# Library dependencies
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy.sql import text

# %% [markdown]
# #### Original Gender Data

# %%
csv_path = "./maryland_covid19-gender_vaccination.csv"
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#    OBJECTID        VACCINATION_DATE            Gender  FirstDoseDaily  \
# 0         1  2021/04/13 15:00:00+00  Federal Entities           84295
# 1         2  2021/04/14 15:00:00+00  Federal Entities             557
# 2         3  2021/04/15 15:00:00+00  Federal Entities             623
# 3         4  2021/04/16 15:00:00+00  Federal Entities             782
# 4         5  2021/04/17 15:00:00+00  Federal Entities            1136
#
#    FirstDoseCumulative  SecondDoseDaily  SecondDoseCumulative  \
# 0                84295          54201.0                 54201
# 1                84852             11.0                 54212
# 2                85475            823.0                 55035
# 3                86257           1016.0                 56051
# 4                87393           1177.0                 57228
#
#    SingleDoseDaily  SingleDoseCumulative
# 0           2952.0                  2952
# 1              1.0                  2953
# 2             19.0                  2972
# 3              8.0                  2980
# 4              6.0                  2986

# %% [markdown]
# #### Resetting Index Values

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#    OBJECTID        VACCINATION_DATE            Gender  FirstDoseDaily  \
# 0         1  2021/04/13 15:00:00+00  Federal Entities           84295
# 1         2  2021/04/14 15:00:00+00  Federal Entities             557
# 2         3  2021/04/15 15:00:00+00  Federal Entities             623
# 3         4  2021/04/16 15:00:00+00  Federal Entities             782
# 4         5  2021/04/17 15:00:00+00  Federal Entities            1136
#
#    FirstDoseCumulative  SecondDoseDaily  SecondDoseCumulative  \
# 0                84295          54201.0                 54201
# 1                84852             11.0                 54212
# 2                85475            823.0                 55035
# 3                86257           1016.0                 56051
# 4                87393           1177.0                 57228
#
#    SingleDoseDaily  SingleDoseCumulative
# 0           2952.0                  2952
# 1              1.0                  2953
# 2             19.0                  2972
# 3              8.0                  2980
# 4              6.0                  2986

# %% [markdown]
# #### Resetting object ID values

# %%
df["OBJECTID"] = np.arange(1,df.shape[0]+1)
df.head()
# Out:
#    OBJECTID        VACCINATION_DATE            Gender  FirstDoseDaily  \
# 0         1  2021/04/13 15:00:00+00  Federal Entities           84295
# 1         2  2021/04/14 15:00:00+00  Federal Entities             557
# 2         3  2021/04/15 15:00:00+00  Federal Entities             623
# 3         4  2021/04/16 15:00:00+00  Federal Entities             782
# 4         5  2021/04/17 15:00:00+00  Federal Entities            1136
#
#    FirstDoseCumulative  SecondDoseDaily  SecondDoseCumulative  \
# 0                84295          54201.0                 54201
# 1                84852             11.0                 54212
# 2                85475            823.0                 55035
# 3                86257           1016.0                 56051
# 4                87393           1177.0                 57228
#
#    SingleDoseDaily  SingleDoseCumulative
# 0           2952.0                  2952
# 1              1.0                  2953
# 2             19.0                  2972
# 3              8.0                  2980
# 4              6.0                  2986

# %%
columnsplit = df['VACCINATION_DATE'].str.split(' ',n=1, expand=True)
# Assigning Column 0 to DATE
df = df.assign(VACCINATION_DATE=columnsplit[0])
df.head()
# Out:
#    OBJECTID VACCINATION_DATE            Gender  FirstDoseDaily  \
# 0         1       2021/04/13  Federal Entities           84295
# 1         2       2021/04/14  Federal Entities             557
# 2         3       2021/04/15  Federal Entities             623
# 3         4       2021/04/16  Federal Entities             782
# 4         5       2021/04/17  Federal Entities            1136
#
#    FirstDoseCumulative  SecondDoseDaily  SecondDoseCumulative  \
# 0                84295          54201.0                 54201
# 1                84852             11.0                 54212
# 2                85475            823.0                 55035
# 3                86257           1016.0                 56051
# 4                87393           1177.0                 57228
#
#    SingleDoseDaily  SingleDoseCumulative
# 0           2952.0                  2952
# 1              1.0                  2953
# 2             19.0                  2972
# 3              8.0                  2980
# 4              6.0                  2986

# %% [markdown]
# #### Converting date from Obect to Date format

# %%
import datetime as dt
df['VACCINATION_DATE'] = pd.to_datetime(df["VACCINATION_DATE"], format='%Y/%m/%d')
df.head()
# Out:
#    OBJECTID VACCINATION_DATE            Gender  FirstDoseDaily  \
# 0         1       2021-04-13  Federal Entities           84295
# 1         2       2021-04-14  Federal Entities             557
# 2         3       2021-04-15  Federal Entities             623
# 3         4       2021-04-16  Federal Entities             782
# 4         5       2021-04-17  Federal Entities            1136
#
#    FirstDoseCumulative  SecondDoseDaily  SecondDoseCumulative  \
# 0                84295          54201.0                 54201
# 1                84852             11.0                 54212
# 2                85475            823.0                 55035
# 3                86257           1016.0                 56051
# 4                87393           1177.0                 57228
#
#    SingleDoseDaily  SingleDoseCumulative
# 0           2952.0                  2952
# 1              1.0                  2953
# 2             19.0                  2972
# 3              8.0                  2980
# 4              6.0                  2986

# %%
df.dtypes
# Out:
# OBJECTID                         int64
# VACCINATION_DATE        datetime64[ns]
# Gender                          object
# FirstDoseDaily                   int64
# FirstDoseCumulative              int64
# SecondDoseDaily                float64
# SecondDoseCumulative             int64
# SingleDoseDaily                float64
# SingleDoseCumulative             int64
# dtype: object

# %% [markdown]
# #### Renaming OBJECTID AND Vaccionation_date columns

# %%
df.rename(columns={"OBJECTID":"ID", "VACCINATION_DATE":"DATE"},inplace=True)
df.head()
# Out:
#    ID       DATE            Gender  FirstDoseDaily  FirstDoseCumulative  \
# 0   1 2021-04-13  Federal Entities           84295                84295
# 1   2 2021-04-14  Federal Entities             557                84852
# 2   3 2021-04-15  Federal Entities             623                85475
# 3   4 2021-04-16  Federal Entities             782                86257
# 4   5 2021-04-17  Federal Entities            1136                87393
#
#    SecondDoseDaily  SecondDoseCumulative  SingleDoseDaily  \
# 0          54201.0                 54201           2952.0
# 1             11.0                 54212              1.0
# 2            823.0                 55035             19.0
# 3           1016.0                 56051              8.0
# 4           1177.0                 57228              6.0
#
#    SingleDoseCumulative
# 0                  2952
# 1                  2953
# 2                  2972
# 3                  2980
# 4                  2986

# %%
df.isnull().sum()
# Out:
# ID                        0
# DATE                      0
# Gender                    0
# FirstDoseDaily            0
# FirstDoseCumulative       0
# SecondDoseDaily          33
# SecondDoseCumulative      0
# SingleDoseDaily         250
# SingleDoseCumulative      0
# dtype: int64

# %% [markdown]
# #### Replacing NaN values with 0

# %%
df = df.replace(np.nan,0)
df
# Out:
#       ID       DATE            Gender  FirstDoseDaily  FirstDoseCumulative  \
# 0      1 2021-04-13  Federal Entities           84295                84295
# 1      2 2021-04-14  Federal Entities             557                84852
# 2      3 2021-04-15  Federal Entities             623                85475
# 3      4 2021-04-16  Federal Entities             782                86257
# 4      5 2021-04-17  Federal Entities            1136                87393
# ..   ...        ...               ...             ...                  ...
# 500  501 2021-05-19              Male           12041              1325837
# 501  502 2021-05-20              Male            7734              1333571
# 502  503 2021-05-21              Male            7379              1340950
# 503  504 2021-05-22              Male            5826              1346776
# 504  505 2021-05-23              Male            1727              1348503
#
#      SecondDoseDaily  SecondDoseCumulative  SingleDoseDaily  \
# 0            54201.0                 54201           2952.0
# 1               11.0                 54212              1.0
# 2              823.0                 55035             19.0
# 3             1016.0                 56051              8.0
# 4             1177.0                 57228              6.0
# ..               ...                   ...              ...
# 500          13859.0               1039781            909.0
# 501          12633.0               1052414           1001.0
# 502          11452.0               1063866            787.0
# 503           6457.0               1070323            613.0
# 504           2315.0               1072638            249.0
#
#      SingleDoseCumulative
# 0                    2952
# 1                    2953
# 2                    2972
# 3                    2980
# 4                    2986
# ..                    ...
# 500                108800
# 501                109801
# 502                110588
# 503                111201
# 504                111450
#
# [505 rows x 9 columns]

# %% [markdown]
# Connecting to DB

# %%
from config import password
connection_string = f"udxenurz:{password}@batyr.db.elephantsql.com/udxenurz"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['cases', 'vaccinations', 'gender']

# %%
# dropping values that are in any of our tables and resetting the index.
with engine.connect() as con:
    statement = [text("""Truncate table gender CASCADE""")]
    for query in statement:
        con.execute(query)

# %%
df.to_sql(name='gender', con=engine, if_exists='append', index=False)
