# %% [markdown]
# # GENDER CLEAN_UP PROCESS

# %%
# Library dependencies
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy.sql import text

# %% [markdown]
# #### Original Gender Data

# %%
csv_path = "./maryland_covid19-gender_vaccination.csv"
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#    OBJECTID        VACCINATION_DATE  Gender  FirstDoseDaily  \
# 0         1  2020/12/14 15:00:00+00  Female               2
# 1         2  2020/12/15 15:00:00+00  Female               9
# 2         3  2020/12/16 15:00:00+00  Female             313
# 3         4  2020/12/17 15:00:00+00  Female             709
# 4         5  2020/12/18 15:00:00+00  Female            1860
#
#    FirstDoseCumulative  SecondDoseDaily  SecondDoseCumulative  \
# 0                    2              NaN                     0
# 1                   11              1.0                     1
# 2                  324              2.0                     3
# 3                 1033              NaN                     3
# 4                 2893              2.0                     5
#
#    SingleDoseDaily  SingleDoseCumulative
# 0              NaN                     0
# 1              NaN                     0
# 2              NaN                     0
# 3              NaN                     0
# 4              NaN                     0

# %% [markdown]
# #### Resetting Index Values

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#    OBJECTID        VACCINATION_DATE  Gender  FirstDoseDaily  \
# 0         1  2020/12/14 15:00:00+00  Female               2
# 1         2  2020/12/15 15:00:00+00  Female               9
# 2         3  2020/12/16 15:00:00+00  Female             313
# 3         4  2020/12/17 15:00:00+00  Female             709
# 4         5  2020/12/18 15:00:00+00  Female            1860
#
#    FirstDoseCumulative  SecondDoseDaily  SecondDoseCumulative  \
# 0                    2              NaN                     0
# 1                   11              1.0                     1
# 2                  324              2.0                     3
# 3                 1033              NaN                     3
# 4                 2893              2.0                     5
#
#    SingleDoseDaily  SingleDoseCumulative
# 0              NaN                     0
# 1              NaN                     0
# 2              NaN                     0
# 3              NaN                     0
# 4              NaN                     0

# %% [markdown]
# #### Resetting object ID values

# %%
df["OBJECTID"] = np.arange(1,df.shape[0]+1)
df.head()
# Out:
#    OBJECTID        VACCINATION_DATE  Gender  FirstDoseDaily  \
# 0         1  2020/12/14 15:00:00+00  Female               2
# 1         2  2020/12/15 15:00:00+00  Female               9
# 2         3  2020/12/16 15:00:00+00  Female             313
# 3         4  2020/12/17 15:00:00+00  Female             709
# 4         5  2020/12/18 15:00:00+00  Female            1860
#
#    FirstDoseCumulative  SecondDoseDaily  SecondDoseCumulative  \
# 0                    2              NaN                     0
# 1                   11              1.0                     1
# 2                  324              2.0                     3
# 3                 1033              NaN                     3
# 4                 2893              2.0                     5
#
#    SingleDoseDaily  SingleDoseCumulative
# 0              NaN                     0
# 1              NaN                     0
# 2              NaN                     0
# 3              NaN                     0
# 4              NaN                     0

# %%
columnsplit = df['VACCINATION_DATE'].str.split(' ',n=1, expand=True)
# Assigning Column 0 to DATE
df = df.assign(VACCINATION_DATE=columnsplit[0])
df.head()
# Out:
#    OBJECTID VACCINATION_DATE  Gender  FirstDoseDaily  FirstDoseCumulative  \
# 0         1       2020/12/14  Female               2                    2
# 1         2       2020/12/15  Female               9                   11
# 2         3       2020/12/16  Female             313                  324
# 3         4       2020/12/17  Female             709                 1033
# 4         5       2020/12/18  Female            1860                 2893
#
#    SecondDoseDaily  SecondDoseCumulative  SingleDoseDaily  \
# 0              NaN                     0              NaN
# 1              1.0                     1              NaN
# 2              2.0                     3              NaN
# 3              NaN                     3              NaN
# 4              2.0                     5              NaN
#
#    SingleDoseCumulative
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %% [markdown]
# #### Converting date from Obect to Date format

# %%
import datetime as dt
df['VACCINATION_DATE'] = pd.to_datetime(df["VACCINATION_DATE"], format='%Y/%m/%d')
df.head()
# Out:
#    OBJECTID VACCINATION_DATE  Gender  FirstDoseDaily  FirstDoseCumulative  \
# 0         1       2020-12-14  Female               2                    2
# 1         2       2020-12-15  Female               9                   11
# 2         3       2020-12-16  Female             313                  324
# 3         4       2020-12-17  Female             709                 1033
# 4         5       2020-12-18  Female            1860                 2893
#
#    SecondDoseDaily  SecondDoseCumulative  SingleDoseDaily  \
# 0              NaN                     0              NaN
# 1              1.0                     1              NaN
# 2              2.0                     3              NaN
# 3              NaN                     3              NaN
# 4              2.0                     5              NaN
#
#    SingleDoseCumulative
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %%
df.dtypes
# Out:
# OBJECTID                         int64
# VACCINATION_DATE        datetime64[ns]
# Gender                          object
# FirstDoseDaily                   int64
# FirstDoseCumulative              int64
# SecondDoseDaily                float64
# SecondDoseCumulative             int64
# SingleDoseDaily                float64
# SingleDoseCumulative             int64
# dtype: object

# %% [markdown]
# #### Renaming OBJECTID AND Vaccionation_date columns

# %%
df.rename(columns={"OBJECTID":"ID", "VACCINATION_DATE":"DATE"},inplace=True)
df.head()
# Out:
#    ID       DATE  Gender  FirstDoseDaily  FirstDoseCumulative  \
# 0   1 2020-12-14  Female               2                    2
# 1   2 2020-12-15  Female               9                   11
# 2   3 2020-12-16  Female             313                  324
# 3   4 2020-12-17  Female             709                 1033
# 4   5 2020-12-18  Female            1860                 2893
#
#    SecondDoseDaily  SecondDoseCumulative  SingleDoseDaily  \
# 0              NaN                     0              NaN
# 1              1.0                     1              NaN
# 2              2.0                     3              NaN
# 3              NaN                     3              NaN
# 4              2.0                     5              NaN
#
#    SingleDoseCumulative
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %%
df.isnull().sum()
# Out:
# ID                        0
# DATE                      0
# Gender                    0
# FirstDoseDaily            0
# FirstDoseCumulative       0
# SecondDoseDaily          33
# SecondDoseCumulative      0
# SingleDoseDaily         250
# SingleDoseCumulative      0
# dtype: int64

# %% [markdown]
# #### Replacing NaN values with 0

# %%
df = df.replace(np.nan,0)
df
# Out:
#       ID       DATE  Gender  FirstDoseDaily  FirstDoseCumulative  \
# 0      1 2020-12-14  Female               2                    2
# 1      2 2020-12-15  Female               9                   11
# 2      3 2020-12-16  Female             313                  324
# 3      4 2020-12-17  Female             709                 1033
# 4      5 2020-12-18  Female            1860                 2893
# ..   ...        ...     ...             ...                  ...
# 508  509 2021-05-21    Male            7660              1342858
# 509  510 2021-05-22    Male            6439              1349297
# 510  511 2021-05-23    Male            3033              1352330
# 511  512 2021-05-24    Male            5712              1358042
# 512  513 2021-05-25    Male            2739              1360781
#
#      SecondDoseDaily  SecondDoseCumulative  SingleDoseDaily  \
# 0                0.0                     0              0.0
# 1                1.0                     1              0.0
# 2                2.0                     3              0.0
# 3                0.0                     3              0.0
# 4                2.0                     5              0.0
# ..               ...                   ...              ...
# 508          11700.0               1066309            811.0
# 509           6961.0               1073270            666.0
# 510           3673.0               1076943            474.0
# 511           6869.0               1083812            782.0
# 512           4522.0               1088334            410.0
#
#      SingleDoseCumulative
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ..                    ...
# 508                111110
# 509                111776
# 510                112250
# 511                113032
# 512                113442
#
# [513 rows x 9 columns]

# %% [markdown]
# #### Converting Non-Gender Values to 'Other'

# %%
genders = ['Male','Female']
df.loc[~df['Gender'].isin(genders), 'Gender'] = 'Other'

# %%
df['Gender'].value_counts()
# Out:
# Other     187
# Female    163
# Male      163
# Name: Gender, dtype: int64

# %% [markdown]
# Connecting to DB

# %%
from config import password, username
connection_string = f"{username}:{password}@batyr.db.elephantsql.com/udxenurz"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['cases', 'gender', 'vaccinations']

# %%
# dropping values that are in any of our tables and resetting the index.
with engine.connect() as con:
    statement = [text("""Truncate table gender CASCADE""")]
    for query in statement:
        con.execute(query)

# %%
df.to_sql(name='gender', con=engine, if_exists='append', index=False)
